# %%
import pandas as pd
import numpy as np
import nltk
from nltk import pos_tag
from nltk.corpus import wordnet as wn

# %%
emotion = pd.read_csv('sample_words (manual exclusions).csv')

# %%
# Ensure you have the required NLTK data files
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jessi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jessi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Define a function to detect past tense and plural forms
def is_past_tense_or_plural(word, pos_tag):
    if pos_tag.startswith('VBD') or pos_tag.startswith('VBN'):  # Past tense verbs
        return True
    if pos_tag.startswith('NNS'):  # Plural nouns
        return True
    return False

# Tag the words with POS tags
emotion['pos_tag'] = emotion['word'].apply(lambda x: pos_tag([x])[0][1])

# Filter the DataFrame
df_filtered = emotion[~emotion.apply(lambda row: is_past_tense_or_plural(row['word'], row['pos_tag']), axis=1)]

# %%
df_filtered
# Out:
#            word   root_word  \
# 0         abhor  abhorrence
# 2    abhorrence  abhorrence
# 4     abhorrent  abhorrence
# 5      abhorrer  abhorrence
# 7     abhorring  abhorrence
# ..          ...         ...
# 873   zealously        zeal
# 875        zest        zest
# 877     zestily        zest
# 878     zesting        zest
# 880       zesty        zest
#
#                                        root_definition  word_id  is_root  \
# 0                            hate coupled with disgust       10    False
# 2                            hate coupled with disgust        9     True
# 4                            hate coupled with disgust       14    False
# 5                            hate coupled with disgust       15    False
# 7                            hate coupled with disgust       17    False
# ..                                                 ...      ...      ...
# 873  a feeling of strong eagerness (usually in favo...     1642    False
# ...

# %%
df_filtered.to_csv('filtered_words.csv', index=False)

# %%
# show me filtered words end with 'ed'
df_filtered[df_filtered['word'].str.endswith('ed')]
# Out:
#              word       root_word  \
# 37        alarmed           alarm
# 60        angered           anger
# 210     delighted         delight
# 216     depressed      depression
# 238  disappointed  disappointment
# 266      dismayed          dismay
# 270    displeased     displeasure
# 276    distressed        distress
# 484      inclined     inclination
# 507     irritated      irritation
# 515      isolated       isolation
# 523         joyed             joy
# 636       pleased        pleasure
# 689     satisfied    satisfaction
# 748     surprised        surprise
# 859       worried           worry
#
#                                        root_definition  word_id  is_root  \
# 37         fear resulting from the awareness of danger       71    False
# 60   a strong emotion; a feeling that is oriented t...      111    False
# 210      a feeling of extreme pleasure or satisfaction      371    False
# 216               sad feelings of gloom and inadequacy      388    False
# ...
